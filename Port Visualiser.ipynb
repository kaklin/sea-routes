# %%
import json

# %% [markdown]
# **Plotly Settings**

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
with open('PUB151_distances.json') as f:
    ports = json.load(f)

# %%
with open('junction_points.json') as f:
    junct = json.load(f)

# %%
def to_decimal(raw):
    """Convert d/m/s representation of long/lat to decimal degrees"""
    d = raw[:raw.index('°')]
    m = raw[raw.index('°')+1:raw.index('\'')]
    s = raw[raw.index('\'')+1:raw.index('"')]
    l = raw[raw.index('"')+1:raw.index('.')]
    decimal = float(d) + float(m)/60. + float(s)/3600.
    if l is 'W' or l is 'S':
        result = -decimal
    else:
        result = decimal
    return result

def parse_location(raw):
    lat, long = raw.split(' ')
    lat = to_decimal(lat)
    long = to_decimal(long)
    return lat, long

# %% [markdown]
# **Plotting all ports**

# %%
ports_temp = {}
for name, rest in ports.items():
    ports_temp[name] = parse_location(rest['location'])

# %%
locs = [loc for name, loc in ports_temp.items()] 

lats = [loc[0] for loc in locs]
longs = [loc[1] for loc in locs]

# %%
flight_path = [ dict(
    type = 'scattergeo',
    lat = lats,
    lon = longs,
    text = [name for name, loc in ports_temp.items()],
    name = 'My Trace',
    mode = 'markers',
    hoverinfo = "text",
    marker = dict(
        symbol = 'hexagon',
        color = 'black',
        size = 3,
    )
) ]
    
layout = dict(
        title = 'All Ports',
        showlegend = False,         
        geo = dict(
            resolution = 50,
            showland = True,
            showlakes = True,
            landcolor = 'rgb(220, 230, 220)',
            countrycolor = 'rgb(250, 250, 250)',
            lakecolor = 'rgb(255, 255, 255)',
            projection = dict( type="natural earth" ),
            coastlinewidth = 0,
            lataxis = dict(
                range = [ -90, 90 ],
#                 range = sorted([source.latitude, dest.latitude]),
                showgrid = False,
                tickmode = "linear",
                dtick = 10
            ),
            lonaxis = dict(
                range = [-180, 180],
#                 range = sorted([source.longitude, dest.longitude]),
                showgrid = False,
                tickmode = "linear",
                dtick = 20
            ),
        )
    )

fig = dict( data=flight_path, layout=layout )
plotly.offline.iplot( fig, validate=False )
# Out:
# <div id="77650cb4-b4df-40d4-b8df-ab81ac1ca958" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("77650cb4-b4df-40d4-b8df-ab81ac1ca958", [{"name": "My Trace", "marker": {"size": 3, "symbol": "hexagon", "color": "black"}, "lon": [11.441666666666666, 12.691666666666666, -10.816666666666666, 141.05, -82.34166666666667, 121.90777777777778, -71.4, 141.55, 170.62861111111113, 174.9763888888889, -82.8, -51.19166666666666, -25.005555555555556, 0.55, 11.490277777777777, 174.04166666666666, 33.94166666666666, 18.433333333333334, -157.46666666666667, -4.030555555555556, -127.45333333333333, 108.2, -55.0, -7.408333333333334, 21.566666666666666, 98.67777777777778, 0.3625, 15.216666666666667, 125.0, 14.115833333333333, 10.063333333333334, 28.231666666666666, 33.4, 109.21666666666667, -64.59166666666667, -83.97500000000001, 121.65, -64.73666666666666, 44.983333333333334, 149.23333333333332, 140.74166666666665, -0.7291666666666666, -85.05, 6.0, 80.00666666666666, -76.19166666666668, 109.15, 7.2, 123.90833333333335, 9.1925, -70.23333333
    mode = 'markers',
    hoverinfo = "text",
    marker = dict(
        symbol = 'hexagon',
        color = 'red',
        size = 4,
    )
) ]
    
layout = dict(
        title = 'Junction Points',
        showlegend = False,         
        geo = dict(
            resolution = 50,
            showland = True,
            showlakes = True,
            landcolor = 'rgb(220, 230, 220)',
            countrycolor = 'rgb(250, 250, 250)',
            lakecolor = 'rgb(255, 255, 255)',
            projection = dict( type="natural earth" ),
            coastlinewidth = 0,
            lataxis = dict(
                range = [ -90, 90 ],
#                 range = sorted([source.latitude, dest.latitude]),
                showgrid = False,
                tickmode = "linear",
                dtick = 10
            ),
            lonaxis = dict(
                range = [-180, 180],
#                 range = sorted([source.longitude, dest.longitude]),
                showgrid = False,
                tickmode = "linear",
                dtick = 20
            ),
        )
    )

fig = dict( data=flight_path, layout=layout )
plotly.offline.iplot( fig, validate=False )
# Out:
# <div id="7385e3db-9d8d-4fe6-810d-c1485de549b9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7385e3db-9d8d-4fe6-810d-c1485de549b9", [{"name": "My Trace", "marker": {"size": 4, "symbol": "hexagon", "color": "red"}, "lon": [18.383333333333333, 10.15, -6.583333333333333, 146.43333333333334, -7.5, 115.71666666666667, -70.9, 142.13333333333333, -85.05, -79.51666666666667, 140.5, -83.0, 140.66666666666666, 32.31666666666667, -5.5, 105.83333333333333, 103.83333333333333, -9.6, 127.45, -3.3333333333333335, -50.0, 115.13333333333334, -5.75, 10.733333333333333, -73.55], "mode": "markers", "text": ["Cape of Good Hope, South Africa", "Nord-Ostsee-Kanal, Germany", "Bishop Rock, England", "Wilson Promontory, Australia", "Inishtrahull, Ireland", "Selat Lombok, Indonesia", "Punta Arenas, Chile", "Torres Strait, Australia", "Yucatan Channel", "Panama, Panama", "Honshu, Japan", "Straits of Florida, U.S.A.", "Tsugaru-Kaikyo, Japan", "Port Said, Egypt", "Ile d\u2019Ouessant, France", "Selat Sunda, Indonesia", "Singapore", "Fastnet Rock, Ireland", "Selat Wetar, Indonesia", "Pentland Firth, Scotland", "Grand Banks South, Atlantic", "Cape Leeuwin, Australia", "Strait of Gibraltar, Gibraltar", "Skagens Odde, Denmark", "Montreal, Canada"], "hoverinfo": "text", "type": "scattergeo", "lat": [-34.36666666666667, 54.36666666666667, 49.75, -39.166666666666664, 55.416666666666664, -8.833333333333334, -53.166666666666664, -10.55, 21.833333333333332, 8.883333333333333, 35.0, 24.416666666666668, 41.5, 31.266666666666666, 48.666666666666664, -6.066666666666666, 1.2666666666666666, 51.333333333333336, -8.316666666666666, 58.7, 42.5, -34.53333333333333, 35.95, 57.8, 45.5]}], {"showlegend": false, "geo": {"lataxis": {"dtick": 10, "range": [-90, 90], "tickmode": "linear", "showgrid": false}, "projection": {"type": "natural earth"}, "resolution": 50, "countrycolor": "rgb(250, 250, 250)", "coastlinewidth": 0, "landcolor": "rgb(220, 230, 220)", "showland": true, "lonaxis": {"dtick": 20, "range": [-180, 180], "tickmode": "linear", "showgrid": false}, "showlakes": true, "lakecolor": "rgb(255, 255, 255)"}, "title": "Junction Points"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
